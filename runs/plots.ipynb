# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

prefixes = ['02_02_', '02_1_', '02_5_', '1_02_', '1_1_', '1_5_', '5_02_', '5_1_', '5_5_']
names = ['grad', 'grad_rad', 'Tstop', 'Tgrow', 'Tsettl', 'Zgr', 'kappa_gr', 'size',
        'rho_gas_cbrt', 'Temperature', 'Press', 'rho_gas_norm', 'Temperature_norm',
        'Env', 'grad_mu', 'grad_ad', 'grad_diff', 'log10(R_0)', 'lambda_mfp', 'c_gas',
        'nu_visc', 'xi_rad', 'kappa_tot', 'Tfourth', 'rho_gas', 'Prandtl_number', 
         'tau_opt', 'Ledoux']
styles = ['r-', 'r--', 'r:', 'g-', 'g--', 'g:', 'b-', 'b--', 'b:']

log_scale = [1 if names[i]=='Tsettl' or names[i]=='Zgr' or names[i]=='kappa_gr' or names[i]=='size' 
      or names[i]=='rho_gas_cbrt' or names[i]=='Temperature' or names[i]=='Press' or
      names[i]=='rho_gas_norm' else 0 for i in range(len(names))]

log_name = [' (log10)' if names[i]=='log10(R_0)' or names[i]=='lambda_mfp' or names[i]=='c_gas'
           or names[i]=='nu_visc' or names[i]=='xi_rad' or names[i]=='kappa_tot' or names[i]=='Tfourth'
           or names[i] == 'rho_gas' or names[i]=='Prandtl_number' or names[i]=='tau_opt' 
           else '' for i in range(len(names))]



def plot_versions(n):
    name = names[n]
    i=0
    for prefix in prefixes:
        R = np.loadtxt('common/'+prefix+'R.txt')
        var = np.loadtxt('common/'+prefix+name+'.txt')
        plt.plot(R, var, styles[i], label=prefix.split('_')[0]+'Au '+prefix.split('_')[1]
                +'Earth Mass')
        i+=1
    if log_scale[n]==1:
        plt.yscale('log')
    plt.grid()
    plt.title(name+log_name[n])
    plt.legend()

# %% [markdown]
# # Solid, Dashed, Dotted line = 0.2, 1, 5 Earth Mass
# # Red, Green, Blue = 0.2, 1, 5 AU

# %%
n = len(names)
plt.figure(figsize=(16, 8*n))
for i in range(n):
    plt.subplot(n,1,i+1)
    plot_versions(i)
